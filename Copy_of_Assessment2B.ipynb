# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
csv1 = pd.read_csv("/content/drive/MyDrive/Copy of college_1.csv")
csv1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
csv2 = pd.read_csv("/content/drive/MyDrive/Copy of college_2.csv")
csv2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(csv1.shape)
# Out:
# (84, 7)

# %%
csv1.insert(4, "computational_thinking", 0)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
csv1.insert(2, "python_en", 0)

# %%
csv1
# Out:
#               Name  python  python_en  mysql  Previous Geekions  \
# 0        A.Dharani    82.0          0   20.0              24500
# 1      V.JEEVITHA     82.0          0   20.0              21740
# 2      HEMAVATHI.R   100.0          0  100.0              19680
# 3      Mugunthan S   100.0          0   47.0              10610
# 4      Sathammai.S   100.0          0    8.0               8980
# ..             ...     ...        ...    ...                ...
# 79    KarthikeyanS    45.0          0    0.0                  0
# 80        BARATH.P    29.0          0    0.0                  0
# 81   N.Ajith kumar    82.0          0    0.0                  0
# 82    mohamed nabi     0.0          0    0.0                  0
# 83  yaser ahamed.A     0.0          0   27.0                  0
#
#     computational_thinking  CodeKata Score  \
# 0                        0           24500
# 1                        0           21740
# 2                        0           19680
# ...

# %%
print(csv1.shape) # shape of ile as changed after inserting the column
# Out:
# (84, 9)

# %%
#merge the 2csv files to 1 with equal columns and many row
frames=[csv1,csv2]
csv1=pd.concat(frames)
csv1
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
print(csv1.shape) # rowa and columns merged and shape of the folder is changed to larger number.
# Out:
# (119, 9)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations=csv1[(csv1['CodeKata Score']>10000)&(csv1['CodeKata Score']<15000)]

# %%
Reached_expectations
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvements=csv1[(csv1['CodeKata Score']>7000)&(csv1['CodeKata Score']<10000)]

# %%
Needs_Improvements
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=csv1[(csv1['CodeKata Score']<7000)]

# %%
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
csv1['Previous Geekions'].mean()
# Out:
# 3842.3529411764707

# %%
csv1['CodeKata Score'].mean()
# Out:
# 4051.764705882353

# %%
cols = ['Previous Geekions', 'CodeKata Score']

csv1[cols].mean().plot(kind='bar');
csv1[cols].mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
No_of_students_participated = csv1.shape[0]

# %%
csv1.shape[0] # mentioioning 0 will print only rows, where rows contain students participation
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
A = csv1['python'].mean()
B = csv1['mysql'].mean()
C = csv1['python_en'].mean()

# %%
print("average completion of python course or my_sql or python_en or computational thinking :", A, B, C)
# Out:
# average completion of python course or my_sql or python_en or computational thinking : 54.35294117647059 23.5 29.65714285714286

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
csv1.sort_values(by=['Rising'],axis=0,ascending=False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking          avg
# 8                      0.0  2385.428571
# 18                     0.0  1942.571429
# 2                      6.0  3094.857143

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
csv1.sort_values(by=["Previous Geekions"],axis=0,ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking     avg
# 0                     NaN  9820.4
# 1                     NaN  8716.4
# 2                     NaN  7912.0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
Department = csv1.groupby('Department')['CodeKata Score'].sum()

# %%
print(Department)
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
Department.plot.pie(autopct="%.1f%%")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
toppers = csv1.groupby('Department')['Name','Department','CodeKata Score'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
print(toppers)
# Out:
#                                                      Name  \
# Department
# Computer Science and Engineering              vijayakumar
# Electronics and Communication Engineering       vignesh B
# Electronics and Electrical Engineering     yaser ahamed.A
#
#                                                                           Department  \
# Department
# Computer Science and Engineering                    Computer Science and Engineering
# Electronics and Communication Engineering  Electronics and Communication Engineering
# Electronics and Electrical Engineering        Electronics and Electrical Engineering
#
#                                            CodeKata Score
# Department
# Computer Science and Engineering                    24500
# Electronics and Communication Engineering           10040
# Electronics and Electrical Engineering              19400

# %%
sb.barplot(x = 'Name',y = 'CodeKata Score' ,hue='Department',data=toppers)
